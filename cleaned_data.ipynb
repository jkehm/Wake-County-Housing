# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
from sklearn.metrics import accuracy_score
from sklearn.svm import SVC
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Import csv
df = pd.read_csv('Resources/cleaned_wake_df.csv')
df.head(10)
# Out:
#    REAL_ESTATE_ID  Township  Deeded_Acreage  Total_sale_Price  Year_Built  \
# 0              19         1            0.21             34500        1964
# 1              20        16            0.46             35500        1970
# 2              22        10            0.46             37500        1900
# 3              25         8            0.96             70000        1971
# 4              30         1            0.47            380000        1946
# 5              31        13            0.39            337500        1970
# 6              33         4            0.50             32500        1969
# 7              34         1            0.70             19500        1968
# 8              35         1            0.49            319000        1938
# 9              37         1            0.13            425000        1921
#
#    HEATED_AREA DESIGN_STYLE BATH Story_Height PHYSICAL_CITY  \
# 0         1828            I    C            A       RALEIGH
# 1         1240            A    A            A       RALEIGH
# 2         2261            A    C            A       WENDELL
# 3         3770            A    J            A       RALEIGH
# 4         1789            A    C            A       RALEIGH
# 5         2463            A    C            A       RALEIGH
# 6         2389            G    E            A       RALEIGH
# 7         1280            A    C            A       RALEIGH
# 8         4650            A    F            B       RALEIGH
# 9         1890            A    C            C       RALEIGH
#
#    PHYSICAL_ZIP_CODE  year  month  Quarter
# 0            27610.0  1974      1        1
# 1            27610.0  1983      5        2
# 2            27591.0  2004      9        3
# 3            27613.0  1971      1        1
# 4            27607.0  2015      8        3
# 5            27615.0  2002      7        3
# 6            27607.0  1979      2        1
# 7            27606.0  1968      1        1
# 8            27608.0  1996      1        1
# 9            27604.0  2008      4        2

# %%
df.dtypes
# Out:
# REAL_ESTATE_ID         int64
# Township               int64
# Deeded_Acreage       float64
# Total_sale_Price       int64
# Year_Built             int64
# HEATED_AREA            int64
# DESIGN_STYLE          object
# BATH                  object
# Story_Height          object
# PHYSICAL_CITY         object
# PHYSICAL_ZIP_CODE    float64
# year                   int64
# month                  int64
# Quarter                int64
# dtype: object

# %%
# General overview of dataset
df.describe()
# Out:
#        REAL_ESTATE_ID       Township  Deeded_Acreage  Total_sale_Price  \
# count   323414.000000  323414.000000   323414.000000      3.234140e+05
# mean    254368.649978      11.492335        0.432250      3.042200e+05
# std     135661.033800       6.408540        1.754607      2.170023e+05
# min         19.000000       1.000000        0.000000      0.000000e+00
# 25%     145265.250000       6.000000        0.130000      1.610000e+05
# 50%     253207.500000      12.000000        0.230000      2.610000e+05
# 75%     358790.750000      17.000000        0.410000      3.905000e+05
# max     504024.000000      20.000000      307.910000      7.940000e+06
#
#           Year_Built    HEATED_AREA  PHYSICAL_ZIP_CODE           year  \
# count  323414.000000  323414.000000      323414.000000  323414.000000
# mean     1996.182843    2289.883614       27571.600843    2011.126958
# std        19.948279    1004.186978          63.981409      10.691870
# min         0.000000     220.000000           0.000000    1956.000000
# 25%      1986.000000    1552.000000       27526.000000    2005.000000
# 50%      2000.000000    2114.000000       27587.000000    2015.000000
# 75%      2009.000000    2818.000000       27610.000000    2019.000000
# max      2024.000000   21993.000000       27713.000000    2023.000000
#
#                month        Quarter
# count  323414.000000  323414.000000
# mean        6.614973       2.532868
# std         3.308460       1.078409
# min         1.000000       1.000000
# 25%         4.000000       2.000000
# 50%         7.000000       3.000000
# 75%         9.000000       3.000000
# max        12.000000       4.000000

# %%
df.describe(percentiles=[0.01,0.05,0.1,0.25,0.75,0.9,0.95,0.99])
# Out:
#        REAL_ESTATE_ID       Township  Deeded_Acreage  Total_sale_Price  \
# count   323414.000000  323414.000000   323414.000000      3.234140e+05
# mean    254368.649978      11.492335        0.432250      3.042200e+05
# std     135661.033800       6.408540        1.754607      2.170023e+05
# min         19.000000       1.000000        0.000000      0.000000e+00
# 1%        6350.390000       1.000000        0.000000      1.491300e+04
# 5%       31251.650000       1.000000        0.030000      6.800000e+04
# 10%      63526.300000       2.000000        0.040000      1.020000e+05
# 25%     145265.250000       6.000000        0.130000      1.610000e+05
# 50%     253207.500000      12.000000        0.230000      2.610000e+05
# 75%     358790.750000      17.000000        0.410000      3.905000e+05
# 90%     445269.700000      20.000000        0.870000      5.500000e+05
# 95%     467640.350000      20.000000        1.190000      6.750000e+05
# 99%     486211.870000      20.000000        3.060000      1.050000e+06
# max     504024.000000      20.000000      307.910000      7.940000e+06
#
#           Year_Built    HEATED_AREA  PHYSICAL_ZIP_CODE           year  \
# count  323414.000000  323414.000000      323414.000000  323414.000000
# mean     1996.182843    2289.883614       27571.600843    2011.126958
# std        19.948279    1004.186978          63.981409      10.691870
# min         0.000000     220.000000           0.000000    1956.000000
# 1%       1928.000000     828.000000       27502.000000    1976.000000
# 5%       1959.000000    1084.000000       27511.000000    1989.000000
# 10%      1970.000000    1224.000000       27513.000000    1996.000000
# 25%      1986.000000    1552.000000       27526.000000    2005.000000
# 50%      2000.000000    2114.000000       27587.000000    2015.000000
# 75%      2009.000000    2818.000000       27610.000000    2019.000000
# 90%      2018.000000    3541.000000       27615.000000    2021.000000
# 95%      2020.000000    4094.000000       27616.000000    2022.000000
# 99%      2022.000000    5498.000000       27617.000000    2023.000000
# max      2024.000000   21993.000000       27713.000000    2023.000000
#
#                month        Quarter
# count  323414.000000  323414.000000
# mean        6.614973       2.532868
# std         3.308460       1.078409
# min         1.000000       1.000000
# 1%          1.000000       1.000000
# 5%          1.000000       1.000000
# 10%         2.000000       1.000000
# 25%         4.000000       2.000000
# 50%         7.000000       3.000000
# 75%         9.000000       3.000000
# 90%        11.000000       4.000000
# 95%        12.000000       4.000000
# 99%        12.000000       4.000000
# max        12.000000       4.000000

# %% [markdown]
# We can see in the Deeded_Acreage that we have a max of 307 acres. Heated area also have a max of 21993 sqft, and Max Sale price is almost 8million Dollars. These are all metrics that will skew the data greatly. The team is considering how to filter the data to have less outlier such as these.
#
# Visualizations to check for outliers/other interesting features

# %%
# Scatter plot total Heated Area x Total Sale Price
plt.scatter(df['HEATED_AREA'], df['Total_sale_Price'])
plt.xlabel('Total Square Feet')
plt.ylabel('Total Sale Price')
plt.title('Total Sale Price vs Total Square Feet')
plt.show()

# %%
# Group data by Year and Avg Sale price
house_price_by_year = df.groupby('year')['Total_sale_Price'].mean()

# Create a line plot to visualize the time series
plt.figure(figsize=(10, 6))
house_price_by_year.plot(kind='line')
plt.xlabel('Year')
plt.ylabel('Total Sale Price AVG')
plt.title('Time Series of House Sale Price by Year')
plt.show()

# %%
# HAVING ISSUES HERE
# Remove bottom 5% and Top 99% of Deeded acreage 3.06, bottom and top 1% (less than $15,000 and greater than $1,050,000)
# Houses between 1% and 99% square feet
# cleaner_df = df.loc[(df['Deeded_Acreage'] > 0.03) | (df['Deeded_Acreage'] <3.06) | (df['Total_sale_Price'] > 15000)
#                  | (df['Total_sale_Price'] < 1050000) | (df['HEATED_AREA'] > 828)  | (df['HEATED_AREA'] < 5498)]
# cleaner_df.head(10)

# Remove bottom 5% and top 1% of Deeded acreage (less than 0.03 and greater than 3.06)
# Remove bottom 1% and top 1% of Total_sale_Price (less than $15,000 and greater than $1,050,000)
# Remove bottom 1% and top 1% of HEATED_AREA (less than 828 and greater than 5,498)
# cleaner_df = df.loc[(df['Deeded_Acreage'] > 0.03) & (df['Deeded_Acreage'] < 3.06) &
#                     (df['Total_sale_Price'] > 15000) & (df['Total_sale_Price'] < 1050000) &
#                     (df['HEATED_AREA'] > 828) & (df['HEATED_AREA'] < 5498)]

# cleaner_df.head(10)

# %%
import numpy as np

# Remove bottom 5% and top 99% of Deeded acreage
lower_cutoff = np.percentile(df['Deeded_Acreage'], 5)
upper_cutoff = np.percentile(df['Deeded_Acreage'], 99)

df = df[(df['Deeded_Acreage'] >= lower_cutoff) & (df['Deeded_Acreage'] <= upper_cutoff)]

df.head(10)
# Out:
#    REAL_ESTATE_ID  Township  Deeded_Acreage  Total_sale_Price  Year_Built  \
# 0              19         1            0.21             34500        1964
# 1              20        16            0.46             35500        1970
# 2              22        10            0.46             37500        1900
# 3              25         8            0.96             70000        1971
# 4              30         1            0.47            380000        1946
# 5              31        13            0.39            337500        1970
# 6              33         4            0.50             32500        1969
# 7              34         1            0.70             19500        1968
# 8              35         1            0.49            319000        1938
# 9              37         1            0.13            425000        1921
#
#    HEATED_AREA DESIGN_STYLE BATH Story_Height PHYSICAL_CITY  \
# 0         1828            I    C            A       RALEIGH
# 1         1240            A    A            A       RALEIGH
# 2         2261            A    C            A       WENDELL
# 3         3770            A    J            A       RALEIGH
# 4         1789            A    C            A       RALEIGH
# 5         2463            A    C            A       RALEIGH
# 6         2389            G    E            A       RALEIGH
# 7         1280            A    C            A       RALEIGH
# 8         4650            A    F            B       RALEIGH
# 9         1890            A    C            C       RALEIGH
#
#    PHYSICAL_ZIP_CODE  year  month  Quarter
# 0            27610.0  1974      1        1
# 1            27610.0  1983      5        2
# 2            27591.0  2004      9        3
# 3            27613.0  1971      1        1
# 4            27607.0  2015      8        3
# 5            27615.0  2002      7        3
# 6            27607.0  1979      2        1
# 7            27606.0  1968      1        1
# 8            27608.0  1996      1        1
# 9            27604.0  2008      4        2

# %%
# Remove values less than $15,000 and greater than $1,050,000
df = df[(df['Total_sale_Price'] >= 15000) & (df['Total_sale_Price'] <= 1050000)]

# Select houses between 1% and 99% square feet
lower_cutoff = np.percentile(df['HEATED_AREA'], 1)
upper_cutoff = np.percentile(df['HEATED_AREA'], 99)

df = df[(df['HEATED_AREA'] >= lower_cutoff) & (df['HEATED_AREA'] <= upper_cutoff)]
df.head(10)
# Out:
#     REAL_ESTATE_ID  Township  Deeded_Acreage  Total_sale_Price  Year_Built  \
# 0               19         1            0.21             34500        1964
# 1               20        16            0.46             35500        1970
# 2               22        10            0.46             37500        1900
# 3               25         8            0.96             70000        1971
# 4               30         1            0.47            380000        1946
# 5               31        13            0.39            337500        1970
# 6               33         4            0.50             32500        1969
# 7               34         1            0.70             19500        1968
# 9               37         1            0.13            425000        1921
# 10              38         1            0.17            364000        1931
#
#     HEATED_AREA DESIGN_STYLE BATH Story_Height PHYSICAL_CITY  \
# 0          1828            I    C            A       RALEIGH
# 1          1240            A    A            A       RALEIGH
# 2          2261            A    C            A       WENDELL
# 3          3770            A    J            A       RALEIGH
# 4          1789            A    C            A       RALEIGH
# 5          2463            A    C            A       RALEIGH
# 6          2389            G    E            A       RALEIGH
# 7          1280            A    C            A       RALEIGH
# 9          1890            A    C            C       RALEIGH
# 10         1500            A    B            J       RALEIGH
#
#     PHYSICAL_ZIP_CODE  year  month  Quarter
# 0             27610.0  1974      1        1
# 1             27610.0  1983      5        2
# 2             27591.0  2004      9        3
# 3             27613.0  1971      1        1
# 4             27607.0  2015      8        3
# 5             27615.0  2002      7        3
# 6             27607.0  1979      2        1
# 7             27606.0  1968      1        1
# 9             27604.0  2008      4        2
# 10            27608.0  2014     12        4

# %%
cleaner_df.describe()
# Out:
#        REAL_ESTATE_ID       Township  Deeded_Acreage  Total_sale_Price  \
# count   284773.000000  284773.000000   284773.000000      2.847730e+05
# mean    256194.298164      11.773346        0.365141      3.024577e+05
# std     136153.997266       6.302043        0.380570      1.733881e+05
# min         19.000000       1.000000        0.040000      1.550000e+04
# 25%     150835.000000       6.000000        0.160000      1.720000e+05
# 50%     253372.000000      12.000000        0.250000      2.720000e+05
# 75%     360494.000000      18.000000        0.410000      3.950000e+05
# max     504024.000000      20.000000        3.050000      1.049000e+06
#
#           Year_Built    HEATED_AREA  PHYSICAL_ZIP_CODE           year  \
# count  284773.000000  284773.000000      284773.000000  284773.000000
# mean     1996.688671    2322.943724       27569.676072    2011.153870
# std        19.626684     867.776515          66.450575      10.466715
# min         0.000000     829.000000           0.000000    1963.000000
# 25%      1987.000000    1649.000000       27526.000000    2005.000000
# 50%      2000.000000    2203.000000       27587.000000    2015.000000
# 75%      2010.000000    2854.000000       27610.000000    2019.000000
# max      2024.000000    5496.000000       27713.000000    2023.000000
#
#                month        Quarter
# count  284773.000000  284773.000000
# mean        6.632219       2.537790
# std         3.298726       1.076536
# min         1.000000       1.000000
# 25%         4.000000       2.000000
# 50%         7.000000       3.000000
# 75%         9.000000       3.000000
# max        12.000000       4.000000

# %%
# df.describe(percentiles=[0.01,0.05,0.1,0.25,0.75,0.9,0.95,0.99])
